# %%
import os
import pandas as pd

# %%
os.listdir('data/Salesforce')
# Out:
# ['ELF', 'Objects']

# %%
os.listdir('data/Salesforce/ELF')
# Out:
# ['LightningError',
#  'LightningInteraction',
#  'LightningPageView',
#  'LightningPerformance',
#  'Report']

# %%
active_reports = pd.read_csv('./datasets/active_reports.csv', low_memory=False, keep_default_na=False)

# %%
active_reports.head()
# Out:
#           CreatedById               CreatedDate  \
# 0  0050b000004KNJdAAO  2021-10-11T06:18:06.000Z
# 1  0050b000004KNJdAAO  2021-10-11T06:18:06.000Z
# 2  0050b000004KNJdAAO  2021-10-11T06:18:06.000Z
# 3  0050b000004KNJdAAO  2021-05-26T09:23:29.000Z
# 4  0050b000004MLeRAAW  2020-02-15T07:34:10.000Z
#
#                              Description                DeveloperName  \
# 0  Test Report with only some parameters                         AnyQ
# 1  Test Report with only some parameters                         AnyQ
# 2  Test Report with only some parameters                         AnyQ
# 3  Test Report with only some parameters                       Main_1
# 4                                         My_Cases_and_Tasks_CARE_t7v
#
#           FolderName   Format                  Id  IsDeleted  \
# 0       Pankaj_Pande  Tabular  00O2R000004F38wUAC      False
# 1       Pankaj_Pande  Tabular  00O2R000004F38wUAC      False
# 2       Pankaj_Pande  Tabular  00O2R000004F38wUAC      False
# 3       Pankaj_Pande  Tabular  00O2R000003zUb9UAE      False
# 4  Dell Care Reports  Tabular  00O2R0000043lHKUAY      False
#
#      LastModifiedById         LastModifiedDate  ... DB_CPU_TIME  \
# 0  0050b000004KNJdAAO  2022-01-04T08:41:10.000  ...        20.0
# 1  0050b000004KNJdAAO  2022-01-04T08:41:10.000  ...        3540
# 2  0050b000004KNJdAAO  2022-01-04T08:41:10.000  ...        4690
# 3  0050b000004KNJdAAO  2021-09-06T12:24:00.000  ...        40.0
# 4  0050b000004MLUkAAO  2021-02-20T17:01:39.000  ...          40
#
#   NUMBER_BUCKETS         TIMESTAMP_DERIVED     USER_ID_DERIVED  \
# 0              1  2022-06-04T12:35:47.938Z  0050b000004KNJdAAO
# 1              1  2022-06-04T02:23:08.584Z  0050b000004KNJdAAO
# 2              1  2022-06-04T01:04:48.613Z  0050b000004KNJdAAO
# 3              1  2022-06-04T22:46:04.525Z  0050b000004KNJdAAO
# 4              0  2022-06-04T05:37:05.980Z  0052R00000APEgvQAH
#
#          CLIENT_IP URI_ID_DERIVED   REPORT_ID_DERIVED                  ORIGIN  \
# 0  168.159.160.201                 00O2R000004F38wUAC  ReportRunFromLightning
# 1  168.159.160.201                 00O2R000004F38wUAC  ReportRunFromLightning
# 2  168.159.160.201                 00O2R000004F38wUAC  ReportRunFromLightning
# 3  168.159.160.201                 00O2R000003zUb9UAE  ReportRunFromLightning
# 4  143.166.255.114                 00O2R0000043lHKUAY  ReportRunFromLightning
#
#   IsActiveSinceCreation  IsActiveSinceLastModification
# 0                  True                          False
# 1                  True                          False
# 2                  True                          False
# 3                  True                          False
# 4                  True                          False
#
# [5 rows x 51 columns]

# %%
active_reports.columns
# Out:
# Index(['CreatedById', 'CreatedDate', 'Description', 'DeveloperName',
#        'FolderName', 'Format', 'Id', 'IsDeleted', 'LastModifiedById',
#        'LastModifiedDate', 'LastReferencedDate', 'LastRunDate',
#        'LastViewedDate', 'Name', 'NamespacePrefix', 'OwnerId',
#        'ReportTypeApiName', 'SystemModstamp', 'EVENT_TYPE', 'TIMESTAMP',
#        'REQUEST_ID', 'ORGANIZATION_ID', 'USER_ID', 'RUN_TIME', 'CPU_TIME',
#        'URI', 'SESSION_KEY', 'LOGIN_KEY', 'USER_TYPE', 'REQUEST_STATUS',
#        'DB_TOTAL_TIME', 'ENTITY_NAME', 'DISPLAY_TYPE', 'RENDERING_TYPE',
#        'REPORT_ID', 'ROW_COUNT', 'NUMBER_EXCEPTION_FILTERS', 'NUMBER_COLUMNS',
#        'AVERAGE_ROW_SIZE', 'SORT', 'DB_BLOCKS', 'DB_CPU_TIME',
#        'NUMBER_BUCKETS', 'TIMESTAMP_DERIVED', 'USER_ID_DERIVED', 'CLIENT_IP',
#        'URI_ID_DERIVED', 'REPORT_ID_DERIVED', 'ORIGIN',
#        'IsActiveSinceCreation', 'IsActiveSinceLastModification'],
#       dtype='object')

# %%
pageview_cols = ['CLIENT_GEO', 'PAGE_URL']
report_obj_cols = ['Id', 'Name']

# %%
ltng_elf_path = 'data/Salesforce/ELF'
ltng_logs = {}

for event_log_file in os.listdir(ltng_elf_path):
    log_path = os.path.join(ltng_elf_path, event_log_file)
    log_samples = os.listdir(log_path)
    random_logs = sorted(log_samples)[0]
    print(random_logs)
    log_name = random_logs.split("_", 1)[-1][:-4]
    if log_name.startswith('Lightning'):
        log_name = log_name[len('Lightning'):]
    ltng_logs[log_name] = pd.read_csv(log_path +"/"+ random_logs, nrows=1000, low_memory=False)
# Out:
# 2022-06-01_LightningError.csv
# 2022-06-04_LightningInteraction.csv
# 2022-06-04_LightningPageView.csv
# 2022-06-04_LightningPerformance.csv
# 2022-06-04_Report.csv

# %%
ltng_pageview = ltng_logs['PageView'][pageview_cols]
report_names = active_reports[report_obj_cols]

# %%
ltng_pageview
# Out:
#               CLIENT_GEO                                           PAGE_URL
# 0     United States/null                               /lightning/page/home
# 1    United States/Texas                               /lightning/page/home
# 2    United States/Texas                               /lightning/page/home
# 3    United States/Texas                               /lightning/page/home
# 4    United States/Texas  /lightning/settings/personal/LanguageAndTimeZo...
# ..                   ...                                                ...
# 995   United States/null  /one/one.app#eyJjb21wb25lbnREZWYiOiJmb3JjZVNlY...
# 996   United States/null          /lightning/r/Case/5006P000005ESO1QAO/view
# 997   United States/null  /lightning/r/Case/5006P000005RdGeQAK/view?ws=%...
# 998   United States/null  /lightning/o/Case/list?filterName=00B2R000005g...
# 999   United States/null          /lightning/r/Case/5006P000004x05ZQAQ/view
#
# [1000 rows x 2 columns]

# %%
ltng_pageview_cleaned = ltng_pageview.dropna(subset=pageview_cols)

# %%
import re

pattern = re.compile(r'\/lightning\/r\/(?P<report_type>[a-zA-Z]{4,})\/(?P<report_id>[0-9a-zA-Z]{18})')

def filter_run_report_endpoints(pattern, url):
    m = re.match(pattern, url)
    if m:
        return m.group('report_id')

# %%
ltng_pageview_cleaned['REPORT_ID_DERIVED'] =\
    ltng_pageview_cleaned.PAGE_URL.apply(lambda url: filter_run_report_endpoints(pattern, url))
# Out:
# C:\Users\Debora\AppData\Local\Temp\ipykernel_14516\2053880511.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ltng_pageview_cleaned['REPORT_ID_DERIVED'] =\

# %%
ltng_pageview_filtered = ltng_pageview_cleaned.dropna(subset=['REPORT_ID_DERIVED'])

# %%
ltng_pageview_filtered
# Out:
#                    CLIENT_GEO  \
# 38         United States/null
# 43         United States/null
# 62         United States/null
# 63   United States/California
# 79         United States/null
# ..                        ...
# 993        United States/null
# 994       United States/Texas
# 996        United States/null
# 997        United States/null
# 999        United States/null
#
#                                               PAGE_URL   REPORT_ID_DERIVED
# 38   /lightning/r/Case/5006P000005egdhQAA/clone?use...  5006P000005egdhQAA
# 43   /lightning/r/Task/00T6P00000I1FUGUA3/view?ws=%...  00T6P00000I1FUGUA3
# 62   /lightning/r/Asset/02i6P000001frFYQAY/view?ws=...  02i6P000001frFYQAY
# 63           /lightning/r/Case/5006P000005LWHSQA4/view  5006P000005LWHSQA4
# 79   /lightning/r/Case/5002R0000171R9bQAE/view?ws=%...  5002R0000171R9bQAE
# ..                                                 ...                 ...
# 993          /lightning/r/Case/5006P000004EKLzQAO/view  5006P000004EKLzQAO
# 994  /lightning/r/WorkOrder/5006P0000052UqbQAE/rela...  5006P0000052UqbQAE
# 996          /lightning/r/Case/5006P000005ESO1QAO/view  5006P000005ESO1QAO
# 997  /lightning/r/Case/5006P000005RdGeQAK/view?ws=%...  5006P000005RdGeQAK
# 999          /lightning/r/Case/5006P000004x05ZQAQ/view  5006P000004x05ZQAQ
#
# [355 rows x 3 columns]

# %%
report_names
# Out:
#                        Id                        Name
# 0      00O2R000004F38wUAC                        AnyQ
# 1      00O2R000004F38wUAC                        AnyQ
# 2      00O2R000004F38wUAC                        AnyQ
# 3      00O2R000003zUb9UAE                         ATM
# 4      00O2R0000043lHKUAY  My Cases and Tasks ( CARE)
# ...                   ...                         ...
# 38280  00O6P000000VEsrUAG        APJ hour SR movement
# 38281  00O2R000004Ii1sUAC                DPD-UDS SLO%
# 38282  00O2R000004Ii1sUAC                DPD-UDS SLO%
# 38283  00O2R000003za0CUAQ              Team Vikas_FCC
# 38284  00O2R000003za0CUAQ              Team Vikas_FCC
#
# [38285 rows x 2 columns]

# %%
report_names.assign(CLIENT_GEO_DERIVED="")
# Out:
#                        Id                        Name CLIENT_GEO_DERIVED
# 0      00O2R000004F38wUAC                        AnyQ
# 1      00O2R000004F38wUAC                        AnyQ
# 2      00O2R000004F38wUAC                        AnyQ
# 3      00O2R000003zUb9UAE                         ATM
# 4      00O2R0000043lHKUAY  My Cases and Tasks ( CARE)
# ...                   ...                         ...                ...
# 38280  00O6P000000VEsrUAG        APJ hour SR movement
# 38281  00O2R000004Ii1sUAC                DPD-UDS SLO%
# 38282  00O2R000004Ii1sUAC                DPD-UDS SLO%
# 38283  00O2R000003za0CUAQ              Team Vikas_FCC
# 38284  00O2R000003za0CUAQ              Team Vikas_FCC
#
# [38285 rows x 3 columns]

# %%
executions_by_region = pd.merge(left=report_names, right=ltng_pageview_filtered, left_on='Id', right_on='REPORT_ID_DERIVED')

# %%
def find_report_geo(report_id):
    reports_with_location = ltng_pageview_filtered.loc[ltng_pageview_filtered['REPORT_ID_DERIVED'] == report_id]
    geo_location = reports_with_location['CLIENT_GEO'].tolist() 
    return geo_location[0] if geo_location else float('NaN')

find_report_geo('5006P000004EKLzQAO')
# Out:
# 'United States/null'

# %%
report_names['CLIENT_GEO_DERIVED'] =\
    report_names.Id.apply(lambda report_id: find_report_geo(report_id))
# Out:
# C:\Users\Debora\AppData\Local\Temp\ipykernel_14516\2596483136.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_names['CLIENT_GEO_DERIVED'] =\

# %%
report_names
# Out:
#                        Id                        Name CLIENT_GEO_DERIVED
# 0      00O2R000004F38wUAC                        AnyQ                NaN
# 1      00O2R000004F38wUAC                        AnyQ                NaN
# 2      00O2R000004F38wUAC                        AnyQ                NaN
# 3      00O2R000003zUb9UAE                         ATM                NaN
# 4      00O2R0000043lHKUAY  My Cases and Tasks ( CARE)                NaN
# ...                   ...                         ...                ...
# 38280  00O6P000000VEsrUAG        APJ hour SR movement                NaN
# 38281  00O2R000004Ii1sUAC                DPD-UDS SLO%                NaN
# 38282  00O2R000004Ii1sUAC                DPD-UDS SLO%                NaN
# 38283  00O2R000003za0CUAQ              Team Vikas_FCC                NaN
# 38284  00O2R000003za0CUAQ              Team Vikas_FCC                NaN
#
# [38285 rows x 3 columns]

# %%
report_names.loc[report_names['CLIENT_GEO_DERIVED'].notnull()]
# Out:
#                        Id               Name   CLIENT_GEO_DERIVED
# 460    00O2R0000043l7WUAQ  Case Aging Report   United States/null
# 461    00O2R0000043l7WUAQ  Case Aging Report   United States/null
# 462    00O2R0000043l7WUAQ  Case Aging Report   United States/null
# 463    00O2R0000043l7WUAQ  Case Aging Report   United States/null
# 464    00O2R0000043l7WUAQ  Case Aging Report   United States/null
# ...                   ...                ...                  ...
# 37278  00O2R0000043lCbUAI  New Email By Team  United States/Texas
# 37279  00O2R0000043lCbUAI  New Email By Team  United States/Texas
# 37280  00O2R0000043lCbUAI  New Email By Team  United States/Texas
# 37281  00O2R0000043lCbUAI  New Email By Team  United States/Texas
# 37282  00O2R0000043lCbUAI  New Email By Team  United States/Texas
#
# [25619 rows x 3 columns]

# %%
report_names.groupby(['CLIENT_GEO_DERIVED'])\
    .agg('count')\
    .reset_index()\
    .rename(columns={'Name': 'ReportName', 'CLIENT_GEO': 'Region'})
# Out:
#              CLIENT_GEO_DERIVED     Id  ReportName
# 0                  China/Fujian     14          14
# 1             India/Maharashtra   3308        3308
# 2                  Ireland/null   2840        2840
# 3                 Japan/Saitama     41          41
# 4      United States/California     64          64
# 5  United States/North Carolina     48          48
# 6           United States/Texas  10039       10039
# 7            United States/null   9265        9265
