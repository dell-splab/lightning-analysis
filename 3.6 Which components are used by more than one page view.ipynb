# %% [markdown]
# # Which components are being used by more than one Page View?

# %% [markdown]
# #### Object used in this study: [Lightning Page View](https://developer.salesforce.com/docs/atlas.en-us.object_reference.meta/object_reference/sforce_api_objects_eventlogfile_lightningpageview.htm)

# %%
import pandas as pd

# %% [markdown]
# ### Loading dataframe

# %%
page_view = pd.read_csv("2022-06-20_LightningPageView.csv")

# %% [markdown]
# ### List all the columns of the current dataframe

# %%
list(page_view.columns)
# Out:
# ['EVENT_TYPE',
#  'TIMESTAMP',
#  'REQUEST_ID',
#  'ORGANIZATION_ID',
#  'USER_ID',
#  'CLIENT_ID',
#  'SESSION_KEY',
#  'LOGIN_KEY',
#  'USER_TYPE',
#  'APP_NAME',
#  'DEVICE_PLATFORM',
#  'SDK_APP_VERSION',
#  'OS_NAME',
#  'OS_VERSION',
#  'USER_AGENT',
#  'BROWSER_NAME',
#  'BROWSER_VERSION',
#  'SDK_VERSION',
#  'DEVICE_MODEL',
#  'DEVICE_ID',
#  'SDK_APP_TYPE',
#  'CLIENT_GEO',
#  'CONNECTION_TYPE',
#  'UI_EVENT_ID',
#  'UI_EVENT_SOURCE',
#  'UI_EVENT_TIMESTAMP',
#  'PAGE_START_TIME',
#  'DURATION',
#  'EFFECTIVE_PAGE_TIME_DEVIATION',
#  'EFFECTIVE_PAGE_TIME_DEVIATION_REASON',
#  'EFFECTIVE_PAGE_TIME_DEVIATION_ERROR_TYPE',
#  'EFFECTIVE_PAGE_TIME',
#  'DEVICE_SESSION_ID',
#  'UI_EVENT_SEQUENCE_NUM',
#  'PAGE_ENTITY_ID',
#  'PAGE_ENTITY_TYPE',
#  'PAGE_CONTEXT',
#  'PAGE_URL',
#  'PAGE_APP_NAME',
#  'PREVPAGE_ENTITY_ID',
#  'PREVPAGE_ENTITY_TYPE',
#  'PREVPAGE_CONTEXT',
#  'PREVPAGE_URL',
#  'PREVPAGE_APP_NAME',
#  'TARGET_UI_ELEMENT',
#  'PARENT_UI_ELEMENT',
#  'GRANDPARENT_UI_ELEMENT',
#  'TIMESTAMP_DERIVED',
#  'USER_ID_DERIVED',
#  'CLIENT_IP']

# %% [markdown]
# ### Counting the values of the Components column

# %%
count = page_view['PAGE_CONTEXT'].value_counts(sort=True)

# %%
print(count.to_string())
# Out:
# one:recordHomeFlexipage2Wrapper                5051
# one:recordHomeFlexipage                        1354
# force:objectHomeDesktop                         751
# forceSearch:searchPageDesktop                   687
# home:landing                                    494
# reports:reportBase                              411
# force:relatedListDesktop                        251
# one:auraContainer                               162
# one:recordActionWrapper                         153
# one:twoColumnLayout                              74
# omni:supervisorPanel                             59
# runtime_sales_activities:taskBorderLayout        37
# forceChatter:desktopChatter                      36
# unknown                                          36
# Prechat                                          31
# runtime_platform_actions:quickActionWrapper      14
# Chat                                             12
# desktopDashboards:dashboard                      11
# Waiting                                          11
# e.forceContent:openPreview                       10
# sfa:analyticsHome                                 6
# forceSearch:searchPage                            5
# forceKnowledge:articleRedirect                    4
# forceSearch:search                                2
# c:AssignedQueueDetails                            2
# app_flexipage:lwcAppFlexipageWrapper              1
# forceChatter:feedElementFullView                  1
# one:alohaPage                                     1
# c:CloneQueueUser                                  1
# notes:notesObjectHome                             1
# sfa:hierarchyFullView                             1
# Postchat                                          1

# %% [markdown]
# ### Resuming dataframe to the columns that we want to use

# %%
resume_page_view = page_view[['PAGE_ENTITY_ID','PAGE_CONTEXT']]

# %% [markdown]
# ### Grouping dataframe by Components

# %%
page_view_group = page_view.groupby(['PAGE_ENTITY_ID', 'PAGE_CONTEXT']).agg({'PAGE_CONTEXT': 'unique'})

# %%
group_resume_pv = resume_page_view.groupby(['PAGE_ENTITY_ID']).agg({'PAGE_CONTEXT': 'unique'})

# %%
group_resume_pv.head(20)
# Out:
#                                                          PAGE_CONTEXT
# PAGE_ENTITY_ID
# 0010b00001tqBrgAAE                  [one:recordHomeFlexipage2Wrapper]
# 0010b00001u3bZbAAI                  [one:recordHomeFlexipage2Wrapper]
# 0010b00001u44cPAAQ                  [one:recordHomeFlexipage2Wrapper]
# 0010b00001uGlwdAAC                  [one:recordHomeFlexipage2Wrapper]
# 0010b000024GigAAAS                  [one:recordHomeFlexipage2Wrapper]
# 0010b000029Q1FQAA0                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002Ar6AEAAZ                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NGHGzAAP                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NGmpxAAD                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NGs9JAAT                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NHEy2AAH  [sfa:hierarchyFullView, one:recordHomeFlexipag...
# 0010b00002NNAjbAAH                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NNwwaAAD                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NODvXAAX                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NOVUZAA5      [runtime_platform_actions:quickActionWrapper]
# 0010b00002NOgbJAAT                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NOrRtAAL                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NPIaPAAX                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NPfRYAA1                          [one:recordHomeFlexipage]
# 0010b00002NPlc4AAD      [runtime_platform_actions:quickActionWrapper]

# %% [markdown]
# ### Setting a list of unique Components and counting one by one

# %%
set_of_unique_pagecontext = list(page_view['PAGE_CONTEXT'].unique())

# %%
def countingPageViews(list_of_pagecontext): 
    count = 0
    for i in list_of_pagecontext:
        count += i in set_of_unique_pagecontext
    return count

# %%
group_resume_pv['componentCounts'] = group_resume_pv['PAGE_CONTEXT'].apply(countingPageViews)

# %%
group_resume_pv.head(20)
# Out:
#                                                          PAGE_CONTEXT  \
# PAGE_ENTITY_ID
# 0010b00001tqBrgAAE                  [one:recordHomeFlexipage2Wrapper]
# 0010b00001u3bZbAAI                  [one:recordHomeFlexipage2Wrapper]
# 0010b00001u44cPAAQ                  [one:recordHomeFlexipage2Wrapper]
# 0010b00001uGlwdAAC                  [one:recordHomeFlexipage2Wrapper]
# 0010b000024GigAAAS                  [one:recordHomeFlexipage2Wrapper]
# 0010b000029Q1FQAA0                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002Ar6AEAAZ                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NGHGzAAP                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NGmpxAAD                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NGs9JAAT                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NHEy2AAH  [sfa:hierarchyFullView, one:recordHomeFlexipag...
# 0010b00002NNAjbAAH                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NNwwaAAD                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NODvXAAX                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NOVUZAA5      [runtime_platform_actions:quickActionWrapper]
# 0010b00002NOgbJAAT                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NOrRtAAL                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NPIaPAAX                  [one:recordHomeFlexipage2Wrapper]
# 0010b00002NPfRYAA1                          [one:recordHomeFlexipage]
# 0010b00002NPlc4AAD      [runtime_platform_actions:quickActionWrapper]
#
#                     componentCounts
# PAGE_ENTITY_ID
# 0010b00001tqBrgAAE                1
# 0010b00001u3bZbAAI                1
# 0010b00001u44cPAAQ                1
# 0010b00001uGlwdAAC                1
# 0010b000024GigAAAS                1
# 0010b000029Q1FQAA0                1
# 0010b00002Ar6AEAAZ                1
# 0010b00002NGHGzAAP                1
# 0010b00002NGmpxAAD                1
# 0010b00002NGs9JAAT                1
# 0010b00002NHEy2AAH                2
# 0010b00002NNAjbAAH                1
# 0010b00002NNwwaAAD                1
# 0010b00002NODvXAAX                1
# 0010b00002NOVUZAA5                1
# 0010b00002NOgbJAAT                1
# 0010b00002NOrRtAAL                1
# 0010b00002NPIaPAAX                1
# 0010b00002NPfRYAA1                1
# 0010b00002NPlc4AAD                1

# %% [markdown]
# ### Counting values and putting in a descending order

# %%
group_resume_pv.sort_values(by='componentCounts', ascending=False)
# Out:
#                                                          PAGE_CONTEXT  \
# PAGE_ENTITY_ID
# a0L6P000000tfMNUAY  [one:recordHomeFlexipage2Wrapper, runtime_plat...
# 5006P000005a1WrQAI  [one:recordActionWrapper, one:recordHomeFlexip...
# 02s6P00000AQTj7QAH  [one:recordHomeFlexipage, one:recordActionWrap...
# a0L6P000000ti0UUAQ  [one:recordHomeFlexipage2Wrapper, runtime_plat...
# a0L6P000000d937UAA  [one:recordHomeFlexipage2Wrapper, runtime_plat...
# ...                                                               ...
# 5006P000004vfaqQAA                  [one:recordHomeFlexipage2Wrapper]
# 5006P000004vBkqQAE                  [one:recordHomeFlexipage2Wrapper]
# 5006P000004uxbpQAA                  [one:recordHomeFlexipage2Wrapper]
# 5006P000004uKUiQAM                  [one:recordHomeFlexipage2Wrapper]
# x1t6P000000wbRrQAI                          [one:recordHomeFlexipage]
#
#                     componentCounts
# PAGE_ENTITY_ID
# a0L6P000000tfMNUAY                2
# 5006P000005a1WrQAI                2
# 02s6P00000AQTj7QAH                2
# a0L6P000000ti0UUAQ                2
# a0L6P000000d937UAA                2
# ...                             ...
# 5006P000004vfaqQAA                1
# 5006P000004vBkqQAE                1
# 5006P000004uxbpQAA                1
# 5006P000004uKUiQAM                1
# x1t6P000000wbRrQAI                1
#
# [5477 rows x 2 columns]

# %% [markdown]
# ### Showing top 10 most used Page Views

# %%
group_resume_pv.sort_values(by='componentCounts', ascending=False).head(10)
# Out:
#                                                          PAGE_CONTEXT  \
# PAGE_ENTITY_ID
# a0L6P000000tfMNUAY  [one:recordHomeFlexipage2Wrapper, runtime_plat...
# 5006P000005a1WrQAI  [one:recordActionWrapper, one:recordHomeFlexip...
# 02s6P00000AQTj7QAH  [one:recordHomeFlexipage, one:recordActionWrap...
# a0L6P000000ti0UUAQ  [one:recordHomeFlexipage2Wrapper, runtime_plat...
# a0L6P000000d937UAA  [one:recordHomeFlexipage2Wrapper, runtime_plat...
# 5006P000005nsKjQAI  [one:recordHomeFlexipage2Wrapper, one:recordAc...
# 5006P000005ntFVQAY  [one:recordActionWrapper, one:recordHomeFlexip...
# 5006P000006CRgPQAW  [one:recordHomeFlexipage2Wrapper, one:recordAc...
# 0WO6P000001yxAbWAI  [one:recordHomeFlexipage, one:recordActionWrap...
# 5006P000005d7WaQAI  [one:recordHomeFlexipage2Wrapper, one:recordAc...
#
#                     componentCounts
# PAGE_ENTITY_ID
# a0L6P000000tfMNUAY                2
# 5006P000005a1WrQAI                2
# 02s6P00000AQTj7QAH                2
# a0L6P000000ti0UUAQ                2
# a0L6P000000d937UAA                2
# 5006P000005nsKjQAI                2
# 5006P000005ntFVQAY                2
# 5006P000006CRgPQAW                2
# 0WO6P000001yxAbWAI                2
# 5006P000005d7WaQAI                2
